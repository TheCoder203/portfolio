// %% [markdown]
// ---
// layout: post
// title: Iteration
// description: Lesson for iteration
// categories: [Javascript, Lesson]
// permalink: /iteration-lesson
// author: Krish K
// codemirror: true
// ---

// %% [markdown]
// ## Iteration
//
// Learning from AstroPlatformer

// %%
%%js
// CODE_RUNNER: iteration

const platforms = [{id:"p1"},{id:"p2"},{id:"p3"}];
for (const p of platforms) {
  console.log("Platform:", p.id);
}
