// %%
---layout: posttitle: Iterationdescription: for loops - iterating over arrayscategories: [Javascript, Lesson]permalink: /iteration-lessonauthor: Krish Kcodemirror: true---

// %% [markdown]
// ## Iteration
//
// Learning from AstroPlatformer

// %%
%%js
const platforms = [{id:"p1"},{id:"p2"},{id:"p3"}];
for (const p of platforms) {
  console.log("Platform:", p.id);
}
