# %% [markdown]
# ---
# layout: post
# title: Table of Completion
# description: table
# categories: [Javascript, Homework]
# permalink: /table
# author: Krish K
# ---

# %% [markdown]
# /* Main dropdown containers */
# .details-folder {
#   margin: 1.2em 0;
#   padding: 1.1em;
#   border: 2px solid transparent;
#   border-radius: 12px;
#   background: linear-gradient(135deg, #111827 0%, #1f2937 100%);
#   box-shadow: 0 4px 15px rgba(0, 0, 0, 0.35);
#   transition: all 0.3s ease;
# }
#
# .details-folder:hover {
#   box-shadow: 0 8px 25px rgba(0, 0, 0, 0.45);
#   transform: translateY(-2px);
# }
#
# /* Category colors */
# .details-folder:nth-of-type(1) {
#   border-color: #FF6B6B;
# }
# .details-folder:nth-of-type(2) {
#   border-color: #4ECDC4;
# }
# .details-folder:nth-of-type(3) {
#   border-color: #FFD93D;
# }
# .details-folder:nth-of-type(4) {
#   border-color: #6BCF7F;
# }
# .details-folder:nth-of-type(5) {
#   border-color: #A78BFA;
# }
# .details-folder:nth-of-type(6) {
#   border-color: #F97316;
# }
# .details-folder:nth-of-type(7) {
#   border-color: #EC4899;
# }
# .details-folder:nth-of-type(8) {
#   border-color: #06B6D4;
# }
#
# /* Main summary text */
# .details-folder summary {
#   color: #f3f4f6;
#   font-weight: 800;
#   font-size: 1.05em;
#   cursor: pointer;
#   outline: none;
#   padding: 0.5em;
#   margin: -0.5em;
#   border-radius: 8px;
#   transition: all 0.2s ease;
# }
#
# .details-folder summary:hover {
#   background-color: rgba(255, 255, 255, 0.06);
#   transform: translateX(4px);
# }
#
# /* Nested dropdowns */
# .details-folder details {
#   margin: 0.8em 0 0 1.2em;
#   padding: 0.8em 1em;
#   border-left: 4px solid;
#   background: #0f172a;
#   border-radius: 8px;
#   box-shadow: inset 0 2px 6px rgba(255, 255, 255, 0.03);
#   transition: all 0.2s ease;
# }
#
# .details-folder details:hover {
#   background: #172033;
# }
#
# /* Colored left borders */
# .details-folder:nth-of-type(1) details { border-left-color: #FF6B6B; }
# .details-folder:nth-of-type(2) details { border-left-color: #4ECDC4; }
# .details-folder:nth-of-type(3) details { border-left-color: #FFD93D; }
# .details-folder:nth-of-type(4) details { border-left-color: #6BCF7F; }
# .details-folder:nth-of-type(5) details { border-left-color: #A78BFA; }
# .details-folder:nth-of-type(6) details { border-left-color: #F97316; }
# .details-folder:nth-of-type(7) details { border-left-color: #EC4899; }
# .details-folder:nth-of-type(8) details { border-left-color: #06B6D4; }
#
# /* Nested summary text */
# .details-folder details summary {
#   color: #e5e7eb;
#   font-weight: 700;
#   font-size: 0.95em;
#   padding: 0.4em 0.6em;
#   border-radius: 6px;
# }
#
# .details-folder details summary:hover {
#   background-color: rgba(255, 255, 255, 0.05);
# }
#
# /* Code blocks */
# .details-folder pre {
#   margin: 0.6em 0 0 0;
#   padding: 0.9em 1.1em;
#   background: linear-gradient(135deg, #020617 0%, #111827 100%);
#   color: #f3f4f6;
#   border-radius: 8px;
#   border-left: 3px solid;
#   white-space: pre-wrap;
#   font-family: 'Monaco', 'Courier New', monospace;
#   font-size: 0.9em;
#   line-height: 1.5;
#   box-shadow: 0 2px 8px rgba(0, 0, 0, 0.3);
# }
#
# /* Header */
# h2 {
#   color: #f9fafb;
#   font-weight: 900;
#   font-size: 2em;
#   margin: 1.5em 0 1em 0;
# }
