# %% [markdown]
# ---
# layout: post
# title: Table of Completion
# description: table
# categories: [Javascript, Homework]
# permalink: /table
# author: Krish K
# ---

# %% [markdown]
# ## College Ready
#
# <style>
# /* Main category styling */
# .details-folder {
#   margin: 1.2em 0;
#   padding: 1.1em;
#   border: 2px solid transparent;
#   border-radius: 12px;
#   background: linear-gradient(135deg, #ffffff 0%, #f8f9ff 100%);
#   box-shadow: 0 4px 15px rgba(0, 0, 0, 0.08);
#   transition: all 0.3s ease;
# }
#
# .details-folder:hover {
#   box-shadow: 0 8px 25px rgba(0, 0, 0, 0.12);
#   transform: translateY(-2px);
# }
#
# /* Category colors */
# .details-folder:nth-of-type(1) { border-color: #FF6B6B; background: linear-gradient(135deg, #FFE5E5 0%, #ffffff 100%); }
# .details-folder:nth-of-type(2) { border-color: #4ECDC4; background: linear-gradient(135deg, #E0F7F6 0%, #ffffff 100%); }
# .details-folder:nth-of-type(3) { border-color: #FFD93D; background: linear-gradient(135deg, #FFFBE6 0%, #ffffff 100%); }
# .details-folder:nth-of-type(4) { border-color: #6BCF7F; background: linear-gradient(135deg, #E8F8ED 0%, #ffffff 100%); }
# .details-folder:nth-of-type(5) { border-color: #A78BFA; background: linear-gradient(135deg, #F3F0FF 0%, #ffffff 100%); }
# .details-folder:nth-of-type(6) { border-color: #F97316; background: linear-gradient(135deg, #FEF3E2 0%, #ffffff 100%); }
# .details-folder:nth-of-type(7) { border-color: #EC4899; background: linear-gradient(135deg, #FCE7F3 0%, #ffffff 100%); }
# .details-folder:nth-of-type(8) { border-color: #06B6D4; background: linear-gradient(135deg, #E0F7FA 0%, #ffffff 100%); }
#
# .details-folder summary {
#   color: #1a1a1a;
#   font-weight: 800;
#   font-size: 1.05em;
#   cursor: pointer;
#   outline: none;
#   padding: 0.5em;
#   margin: -0.5em;
#   border-radius: 8px;
#   transition: all 0.2s ease;
# }
#
# .details-folder summary:hover {
#   background-color: rgba(0, 0, 0, 0.03);
#   transform: translateX(4px);
# }
#
# /* Topic page links */
# .topic-page-link {
#   text-decoration: none;
#   display: inline-block;
#   margin-top: 0.8em;
# }
#
# .topic-page-link div {
#   background: linear-gradient(135deg, #3884ff 0%, #2563eb 100%);
#   color: white;
#   padding: 10px 16px;
#   border-radius: 8px;
#   font-weight: 700;
#   display: inline-block;
#   box-shadow: 0 4px 12px rgba(56, 132, 255, 0.3);
#   transition: all 0.3s ease;
#   cursor: pointer;
#   border: 2px solid transparent;
# }
#
# .topic-page-link div:hover {
#   transform: translateY(-3px);
#   box-shadow: 0 6px 20px rgba(56, 132, 255, 0.4);
#   background: linear-gradient(135deg, #2563eb 0%, #1d4ed8 100%);
# }
#
# .topic-page-link div:active {
#   transform: translateY(-1px);
# }
#
# h2 {
#   color: #1a1a2e;
#   font-weight: 900;
#   font-size: 2em;
#   margin: 1.5em 0 1em 0;
# }
#
# .topic-button {
#   display: inline-block;
#   text-decoration: none !important;
#   margin: 8px;
#   padding: 12px 18px;
#   border-radius: 10px;
#   font-weight: 700;
#   color: #1a1a1a !important;
#   background: white;
#   border: 2px solid #ddd;
#   transition: all 0.25s ease;
# }
#
# .topic-button:hover {
#   transform: translateY(-2px);
#   box-shadow: 0 6px 16px rgba(0,0,0,.12);
# }
# </style>
#
# <!-- OOP -->
# <!-- OOP -->
#
# <details class="details-folder">
#   <summary>OOP</summary>
#
#   <a class="topic-button" href="{{site.baseurl}}/writing-classes">
#     Writing Classes
#   </a>
#
#   <a class="topic-button" href="{{site.baseurl}}/methods-parameters">
#     Methods & Parameters
#   </a>
#
#   <a class="topic-button" href="{{site.baseurl}}/instantiation-objects">
#     Instantiation & Objects
#   </a>
#
#   <a class="topic-button" href="{{site.baseurl}}/inheritance-basic">
#     Inheritance (Basic)
#   </a>
#
#   <a class="topic-button" href="{{site.baseurl}}/method-overriding">
#     Method Overriding
#   </a>
#
#   <a class="topic-button" href="{{site.baseurl}}/constructor-chaining">
#     Constructor Chaining
#   </a>
#
# </details>
#
# <!-- Control Structures -->
# <details class="details-folder">
# <summary>Control Structures</summary>
#
# <div class="topic-grid">
#
# <a class="topic-card" href="{{site.baseurl}}/iteration">
# Iteration
# <span>Open Topic →</span>
# </a>
#
# <a class="topic-card" href="{{site.baseurl}}/conditionals">
# Conditionals
# <span>Open Topic →</span>
# </a>
#
# <a class="topic-card" href="{{site.baseurl}}/nested-conditions">
# Nested Conditions
# <span>Open Topic →</span>
# </a>
#
# </div>
#
# </details>
#
# <!-- Data Types -->
# <details class="details-folder">
# <summary>Data Types</summary>
#
# <div class="topic-grid">
#
# <a class="topic-card" href="{{site.baseurl}}/numbers">
# Numbers
# <span>Open Topic →</span>
# </a>
#
# <a class="topic-card" href="{{site.baseurl}}/strings">
# Strings
# <span>Open Topic →</span>
# </a>
#
# <a class="topic-card" href="{{site.baseurl}}/booleans">
# Booleans
# <span>Open Topic →</span>
# </a>
#
# <a class="topic-card" href="{{site.baseurl}}/arrays">
# Arrays
# <span>Open Topic →</span>
# </a>
#
# <a class="topic-card" href="{{site.baseurl}}/objects-json">
# Objects (JSON)
# <span>Open Topic →</span>
# </a>
#
# </div>
#
# </details>
#
#
#
# <!-- Operators -->
# <details class="details-folder">
# <summary>Operators</summary>
#
# <div class="topic-grid">
#
# <a class="topic-card" href="{{site.baseurl}}/mathematical-operators">
# Mathematical Operators
# <span>Open Topic →</span>
# </a>
#
# <a class="topic-card" href="{{site.baseurl}}/string-operations">
# String Operations
# <span>Open Topic →</span>
# </a>
#
# <a class="topic-card" href="{{site.baseurl}}/boolean-expressions">
# Boolean Expressions
# <span>Open Topic →</span>
# </a>
#
# </div>
# </details>
#
# <!-- Input/Output -->
# <details class="details-folder">
# <summary>Input/Output</summary>
#
# <div class="topic-grid">
#
# <a class="topic-card" href="{{site.baseurl}}/keyboard-input">
# Keyboard Input
# <span>Open Topic →</span>
# </a>
#
# <a class="topic-card" href="{{site.baseurl}}/canvas-rendering">
# Canvas Rendering
# <span>Open Topic →</span>
# </a>
#
# <a class="topic-card" href="{{site.baseurl}}/gameenv-configuration">
# GameEnv Configuration
# <span>Open Topic →</span>
# </a>
#
# <a class="topic-card" href="{{site.baseurl}}/api-integration">
# API Integration
# <span>Open Topic →</span>
# </a>
#
# <a class="topic-card" href="{{site.baseurl}}/asynchronous-io">
# Asynchronous I/O
# <span>Open Topic →</span>
# </a>
#
# <a class="topic-card" href="{{site.baseurl}}/json-parsing">
# JSON Parsing
# <span>Open Topic →</span>
# </a>
#
# </div>
# </details>
#
# <!-- Documentation -->
# <details class="details-folder">
# <summary>Documentation</summary>
#
# <div class="topic-grid">
#
# <a class="topic-card" href="{{site.baseurl}}/code-comments">
# Code Comments
# <span>Open Topic →</span>
# </a>
#
# <a class="topic-card" href="{{site.baseurl}}/documentation">
# Documentation
# <span>Open Topic →</span>
# </a>
#
# </div>
# </details>
#
# <!-- Debugging -->
# <details class="details-folder">
# <summary>Debugging</summary>
#
# <div class="topic-grid">
#
# <a class="topic-card" href="{{site.baseurl}}/console-debugging">
# Console Debugging
# <span>Open Topic →</span>
# </a>
#
# <a class="topic-card" href="{{site.baseurl}}/hit-box-visualization">
# Hit Box Visualization
# <span>Open Topic →</span>
# </a>
#
# <a class="topic-card" href="{{site.baseurl}}/source-level-debugging">
# Source-Level Debugging
# <span>Open Topic →</span>
# </a>
#
# <a class="topic-card" href="{{site.baseurl}}/network-debugging">
# Network Debugging
# <span>Open Topic →</span>
# </a>
#
# <a class="topic-card" href="{{site.baseurl}}/application-debugging">
# Application Debugging
# <span>Open Topic →</span>
# </a>
#
# <a class="topic-card" href="{{site.baseurl}}/element-inspection">
# Element Inspection
# <span>Open Topic →</span>
# </a>
#
# </div>
# </details>
#
# <!-- Testing & Verification -->
# <details class="details-folder">
# <summary>Testing & Verification</summary>
#
# <div class="topic-grid">
#
# <a class="topic-card" href="{{site.baseurl}}/gameplay-testing">
# Gameplay Testing
# <span>Open Topic →</span>
# </a>
#
# <a class="topic-card" href="{{site.baseurl}}/integration-testing">
# Integration Testing
# <span>Open Topic →</span>
# </a>
#
# <a class="topic-card" href="{{site.baseurl}}/api-error-handling">
# API Error Handling
# <span>Open Topic →</span>
# </a>
#
# </div>
# </details>
