# %% [markdown]
# ---
# layout: post
# title: Table of Completion
# description: table
# categories: [Javascript, Homework]
# permalink: /table
# author: Krish K
# ---

# %% [markdown]
# ## Assessment Evidence Table
#
# | Learning Objective | File name | Where to find it | How it's implemented |
# | --- | --- | --- | --- |
# | Writing Classes | `allhw.ipynb`, `astroplatformer.js`, `astromusic.js`, `astrodeath.js` | `_notebooks/2026-5-13-allhw.ipynb`, `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, `_projects/games/astronaut-platformer-game/levels/astromusic.js`, `_projects/games/astronaut-platformer-game/levels/astrodeath.js` | Defines multiple classes in notebook examples and game level classes in platformer, music, and death levels. |
# | Methods & Parameters | `allhw.ipynb`, `astroplatformer.js` | `_notebooks/2026-5-13-allhw.ipynb`, `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Functions with parameters like `Login(_username, _password)`, `scaleCoin(source, sx, sy)`, and `_die(reason)` manage behavior and state. |
# | Instantiation & Objects | `astroplatformer.js` | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | `this.classes = [...]` registers game objects; `new Leaderboard(...)` and `gameEnv.stats` instantiate runtime objects. |
# | Inheritance (Basic) | `allhw.ipynb`, `astroplatformer.js` | `_notebooks/2026-5-13-allhw.ipynb`, `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | `class ElectricCar extends Car` and `class FixedPlatformerCoin extends Coin` show subclassing. |
# | Method Overriding | `astroplatformer.js` | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Overrides `update()` and `collect()` in `FixedPlatformerCoin` to customize coin behavior. |
# | Constructor Chaining | `allhw.ipynb` | `_notebooks/2026-5-13-allhw.ipynb` | `super(make, model, fuel)` in `ElectricCar` demonstrates chaining parent constructors. |
# | Iteration | `allhw.ipynb`, `astroplatformer.js` | `_notebooks/2026-5-13-allhw.ipynb`, `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Uses `for...of`, `while`, and `.map()` to loop through arrays of objects and game logic. |
# | Conditionals | `astroplatformer.js` | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Many `if/else if/else` branches handle physics, collisions, player death, and win conditions. |
# | Nested Conditions | `astroplatformer.js` | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Nested collision logic is used for platform top, ceiling, and wall detection. |
# | Numbers | `astroplatformer.js` | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Numeric properties for position, velocity, scale, coins, lives, and physics calculations. |
# | Strings | `astroplatformer.js` | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | File paths, HUD text, template literals, and status messages. |
# | Booleans | `astroplatformer.js` | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Flags like `_isDead`, `_won`, `keys.w`, `collected`, and `userActivated`. |
# | Arrays | `astroplatformer.js` | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Arrays for `_platforms`, `_spikes`, `_coinPositions`, and keyboard state. |
# | Objects (JSON) | `astroplatformer.js` | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | `playerData`, `baseLayout`, `coinData`, and scaled platform objects. |
# | Mathematical Operators | `astroplatformer.js` | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Uses `+`, `-`, `*`, `/`, and `Math.min` for movement, gravity, and collision math. |
# | String Operations | `astroplatformer.js` | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Path concatenation and template literal generation for UI and assets. |
# | Boolean Expressions | `astroplatformer.js` | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Compound conditions for collision detection and input handling. |
# | Keyboard Input | `astroplatformer.js` | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | `document.addEventListener('keydown', this._keyDown)` and `keyup` handle WASD/arrow input. |
# | Canvas Rendering | `astroplatformer.js` | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Sets up game object classes and overlay DOM elements for rendering via the game engine. |
# | GameEnv Configuration | `astroplatformer.js` | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Uses `gameEnv.path`, `gameEnv.innerWidth`, `gameEnv.innerHeight`, and `gameEnv.stats`. |
# | API Integration | `astromusic.js`, `astroplatformer.js` | `_projects/games/astronaut-platformer-game/levels/astromusic.js`, `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | `fetch(url)` to iTunes API and `Leaderboard.submitScore(...)` in platformer. |
# | Asynchronous I/O | `astromusic.js` | `_projects/games/astronaut-platformer-game/levels/astromusic.js` | `async fetchPreviewUrl()` and `await response.json()` show async flow. |
# | JSON Parsing | `astromusic.js` | `_projects/games/astronaut-platformer-game/levels/astromusic.js` | Parses API response with `await response.json()`. |
# | Code Comments | `astroplatformer.js` | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Extensive inline comments document physics, collision, and level setup. |
# | Documentation | `ASTROGRAVBLOG.md` | `_projects/games/astronaut-platformer-game/ASTROGRAVBLOG.md` | Game setup and narrative notes are documented in the level page. |
# | Console Debugging | `astromusic.js` | `_projects/games/astronaut-platformer-game/levels/astromusic.js` | `console.log` and `console.warn` trace API and music start behavior. |
# | Hit Box Visualization | `astroplatformer.js` | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Hitbox values and collision boundary checks are computed and explained in comments. |
# | Gameplay Testing | `astroplatformer.js` | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Full playable level with movement, coins, win condition, and death flow. |
# | Integration Testing | `astromusic.js`, `astroplatformer.js` | `_projects/games/astronaut-platformer-game/levels/astromusic.js`, `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | API fetch and leaderboard submission show real integration points. |
# | API Error Handling | `astromusic.js` | `_projects/games/astronaut-platformer-game/levels/astromusic.js` | `try/catch` around fetch and JSON parsing handles API failures. |

# %%
## Interactive Topic Explorer

<style>
.details-folder {
  margin: 0.9em 0;
  padding: 0.9em;
  border: 1px solid #ccc;
  border-radius: 8px;
  background: #fbfbfb;
}
.details-folder summary {
  font-size: 1.05em;
  font-weight: 700;
  cursor: pointer;
}
.topic-buttons {
  margin: 0.75em 0;
}
.topic-buttons button {
  margin: 0.25em 0.35em 0.25em 0;
  padding: 0.55em 0.9em;
  border: 1px solid #3884ff;
  border-radius: 6px;
  background: #fff;
  color: #0b3b91;
  cursor: pointer;
}
.topic-buttons button:hover {
  background: #eef4ff;
}
.code-snippet {
  display: none;
  margin-top: 0.75em;
  padding: 0.85em;
  background: #1f2937;
  color: #f8fafc;
  border-radius: 8px;
  white-space: pre-wrap;
  font-family: monospace;
}
</style>

<script>
function toggleSnippet(id) {
  var el = document.getElementById(id);
  if (!el) return;
  el.style.display = el.style.display === 'block' ? 'none' : 'block';
}
</script>

<details class="details-folder"><summary>Writing Classes</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('writing-classes-files')">Files</button>
<button onclick="toggleSnippet('writing-classes-locations')">Locations</button>
<button onclick="toggleSnippet('writing-classes-implementation')">Implementation</button>
</div>
<pre id="writing-classes-files" class="code-snippet">allhw.ipynb
astroplatformer.js
astromusic.js
astrodeath.js</pre>
<pre id="writing-classes-locations" class="code-snippet">_notebooks/2026-5-13-allhw.ipynb
_projects/games/astronaut-platformer-game/levels/astroplatformer.js
_projects/games/astronaut-platformer-game/levels/astromusic.js
_projects/games/astronaut-platformer-game/levels/astrodeath.js</pre>
<pre id="writing-classes-implementation" class="code-snippet">Defines multiple classes in notebook examples and game level classes in platformer, music, and death levels.</pre>
</details>

<details class="details-folder"><summary>Methods & Parameters</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('methods-parameters-files')">Files</button>
<button onclick="toggleSnippet('methods-parameters-locations')">Locations</button>
<button onclick="toggleSnippet('methods-parameters-implementation')">Implementation</button>
</div>
<pre id="methods-parameters-files" class="code-snippet">allhw.ipynb
astroplatformer.js</pre>
<pre id="methods-parameters-locations" class="code-snippet">_notebooks/2026-5-13-allhw.ipynb
_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
<pre id="methods-parameters-implementation" class="code-snippet">Functions with parameters like Login(_username, _password), scaleCoin(source, sx, sy), and _die(reason) manage behavior and state.</pre>
</details>

<details class="details-folder"><summary>Instantiation & Objects</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('instantiation-objects-files')">Files</button>
<button onclick="toggleSnippet('instantiation-objects-locations')">Locations</button>
<button onclick="toggleSnippet('instantiation-objects-implementation')">Implementation</button>
</div>
<pre id="instantiation-objects-files" class="code-snippet">astroplatformer.js</pre>
<pre id="instantiation-objects-locations" class="code-snippet">_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
<pre id="instantiation-objects-implementation" class="code-snippet">this.classes = [...] registers game objects; new Leaderboard(...) and gameEnv.stats instantiate runtime objects.</pre>
</details>

<details class="details-folder"><summary>Inheritance (Basic)</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('inheritance-basic-files')">Files</button>
<button onclick="toggleSnippet('inheritance-basic-locations')">Locations</button>
<button onclick="toggleSnippet('inheritance-basic-implementation')">Implementation</button>
</div>
<pre id="inheritance-basic-files" class="code-snippet">allhw.ipynb
astroplatformer.js</pre>
<pre id="inheritance-basic-locations" class="code-snippet">_notebooks/2026-5-13-allhw.ipynb
_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
<pre id="inheritance-basic-implementation" class="code-snippet">class ElectricCar extends Car and class FixedPlatformerCoin extends Coin show subclassing.</pre>
</details>

<details class="details-folder"><summary>Method Overriding</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('method-overriding-files')">Files</button>
<button onclick="toggleSnippet('method-overriding-locations')">Locations</button>
<button onclick="toggleSnippet('method-overriding-implementation')">Implementation</button>
</div>
<pre id="method-overriding-files" class="code-snippet">astroplatformer.js</pre>
<pre id="method-overriding-locations" class="code-snippet">_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
<pre id="method-overriding-implementation" class="code-snippet">Overrides update() and collect() in FixedPlatformerCoin to customize coin behavior.</pre>
</details>

<details class="details-folder"><summary>Constructor Chaining</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('constructor-chaining-files')">Files</button>
<button onclick="toggleSnippet('constructor-chaining-locations')">Locations</button>
<button onclick="toggleSnippet('constructor-chaining-implementation')">Implementation</button>
</div>
<pre id="constructor-chaining-files" class="code-snippet">allhw.ipynb</pre>
<pre id="constructor-chaining-locations" class="code-snippet">_notebooks/2026-5-13-allhw.ipynb</pre>
<pre id="constructor-chaining-implementation" class="code-snippet">super(make, model, fuel) in ElectricCar demonstrates chaining parent constructors.</pre>
</details>

<details class="details-folder"><summary>Iteration</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('iteration-files')">Files</button>
<button onclick="toggleSnippet('iteration-locations')">Locations</button>
<button onclick="toggleSnippet('iteration-implementation')">Implementation</button>
</div>
<pre id="iteration-files" class="code-snippet">allhw.ipynb
astroplatformer.js</pre>
<pre id="iteration-locations" class="code-snippet">_notebooks/2026-5-13-allhw.ipynb
_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
<pre id="iteration-implementation" class="code-snippet">Uses for...of, while, and .map() to loop through arrays of objects and game logic.</pre>
</details>

<details class="details-folder"><summary>Conditionals</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('conditionals-files')">Files</button>
<button onclick="toggleSnippet('conditionals-locations')">Locations</button>
<button onclick="toggleSnippet('conditionals-implementation')">Implementation</button>
</div>
<pre id="conditionals-files" class="code-snippet">astroplatformer.js</pre>
<pre id="conditionals-locations" class="code-snippet">_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
<pre id="conditionals-implementation" class="code-snippet">Many if/else if/else branches handle physics, collisions, player death, and win conditions.</pre>
</details>

<details class="details-folder"><summary>Nested Conditions</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('nested-conditions-files')">Files</button>
<button onclick="toggleSnippet('nested-conditions-locations')">Locations</button>
<button onclick="toggleSnippet('nested-conditions-implementation')">Implementation</button>
</div>
<pre id="nested-conditions-files" class="code-snippet">astroplatformer.js</pre>
<pre id="nested-conditions-locations" class="code-snippet">_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
<pre id="nested-conditions-implementation" class="code-snippet">Nested collision logic is used for platform top, ceiling, and wall detection.</pre>
</details>

<details class="details-folder"><summary>Numbers</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('numbers-files')">Files</button>
<button onclick="toggleSnippet('numbers-locations')">Locations</button>
<button onclick="toggleSnippet('numbers-implementation')">Implementation</button>
</div>
<pre id="numbers-files" class="code-snippet">astroplatformer.js</pre>
<pre id="numbers-locations" class="code-snippet">_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
<pre id="numbers-implementation" class="code-snippet">Numeric properties for position, velocity, scale, coins, lives, and physics calculations.</pre>
</details>

<details class="details-folder"><summary>Strings</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('strings-files')">Files</button>
<button onclick="toggleSnippet('strings-locations')">Locations</button>
<button onclick="toggleSnippet('strings-implementation')">Implementation</button>
</div>
<pre id="strings-files" class="code-snippet">astroplatformer.js</pre>
<pre id="strings-locations" class="code-snippet">_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
<pre id="strings-implementation" class="code-snippet">File paths, HUD text, template literals, and status messages.</pre>
</details>

<details class="details-folder"><summary>Booleans</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('booleans-files')">Files</button>
<button onclick="toggleSnippet('booleans-locations')">Locations</button>
<button onclick="toggleSnippet('booleans-implementation')">Implementation</button>
</div>
<pre id="booleans-files" class="code-snippet">astroplatformer.js</pre>
<pre id="booleans-locations" class="code-snippet">_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
<pre id="booleans-implementation" class="code-snippet">Flags like _isDead, _won, keys.w, collected, and userActivated.</pre>
</details>

<details class="details-folder"><summary>Arrays</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('arrays-files')">Files</button>
<button onclick="toggleSnippet('arrays-locations')">Locations</button>
<button onclick="toggleSnippet('arrays-implementation')">Implementation</button>
</div>
<pre id="arrays-files" class="code-snippet">astroplatformer.js</pre>
<pre id="arrays-locations" class="code-snippet">_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
<pre id="arrays-implementation" class="code-snippet">Arrays for _platforms, _spikes, _coinPositions, and keyboard state.</pre>
</details>

<details class="details-folder"><summary>Objects (JSON)</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('objects-json-files')">Files</button>
<button onclick="toggleSnippet('objects-json-locations')">Locations</button>
<button onclick="toggleSnippet('objects-json-implementation')">Implementation</button>
</div>
<pre id="objects-json-files" class="code-snippet">astroplatformer.js</pre>
<pre id="objects-json-locations" class="code-snippet">_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
<pre id="objects-json-implementation" class="code-snippet">playerData, baseLayout, coinData, and scaled platform objects.</pre>
</details>

<details class="details-folder"><summary>Mathematical Operators</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('mathematical-operators-files')">Files</button>
<button onclick="toggleSnippet('mathematical-operators-locations')">Locations</button>
<button onclick="toggleSnippet('mathematical-operators-implementation')">Implementation</button>
</div>
<pre id="mathematical-operators-files" class="code-snippet">astroplatformer.js</pre>
<pre id="mathematical-operators-locations" class="code-snippet">_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
<pre id="mathematical-operators-implementation" class="code-snippet">Uses +, -, *, /, and Math.min for movement, gravity, and collision math.</pre>
</details>

<details class="details-folder"><summary>String Operations</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('string-operations-files')">Files</button>
<button onclick="toggleSnippet('string-operations-locations')">Locations</button>
<button onclick="toggleSnippet('string-operations-implementation')">Implementation</button>
</div>
<pre id="string-operations-files" class="code-snippet">astroplatformer.js</pre>
<pre id="string-operations-locations" class="code-snippet">_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
<pre id="string-operations-implementation" class="code-snippet">Path concatenation and template literal generation for UI and assets.</pre>
</details>

<details class="details-folder"><summary>Boolean Expressions</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('boolean-expressions-files')">Files</button>
<button onclick="toggleSnippet('boolean-expressions-locations')">Locations</button>
<button onclick="toggleSnippet('boolean-expressions-implementation')">Implementation</button>
</div>
<pre id="boolean-expressions-files" class="code-snippet">astroplatformer.js</pre>
<pre id="boolean-expressions-locations" class="code-snippet">_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
<pre id="boolean-expressions-implementation" class="code-snippet">Compound conditions for collision detection and input handling.</pre>
</details>

<details class="details-folder"><summary>Keyboard Input</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('keyboard-input-files')">Files</button>
<button onclick="toggleSnippet('keyboard-input-locations')">Locations</button>
<button onclick="toggleSnippet('keyboard-input-implementation')">Implementation</button>
</div>
<pre id="keyboard-input-files" class="code-snippet">astroplatformer.js</pre>
<pre id="keyboard-input-locations" class="code-snippet">_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
<pre id="keyboard-input-implementation" class="code-snippet">document.addEventListener('keydown', this._keyDown) and keyup handle WASD/arrow input.</pre>
</details>

<details class="details-folder"><summary>Canvas Rendering</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('canvas-rendering-files')">Files</button>
<button onclick="toggleSnippet('canvas-rendering-locations')">Locations</button>
<button onclick="toggleSnippet('canvas-rendering-implementation')">Implementation</button>
</div>
<pre id="canvas-rendering-files" class="code-snippet">astroplatformer.js</pre>
<pre id="canvas-rendering-locations" class="code-snippet">_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
<pre id="canvas-rendering-implementation" class="code-snippet">Sets up game object classes and overlay DOM elements for rendering via the game engine.</pre>
</details>

<details class="details-folder"><summary>GameEnv Configuration</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('gameenv-configuration-files')">Files</button>
<button onclick="toggleSnippet('gameenv-configuration-locations')">Locations</button>
<button onclick="toggleSnippet('gameenv-configuration-implementation')">Implementation</button>
</div>
<pre id="gameenv-configuration-files" class="code-snippet">astroplatformer.js</pre>
<pre id="gameenv-configuration-locations" class="code-snippet">_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
<pre id="gameenv-configuration-implementation" class="code-snippet">Uses gameEnv.path, gameEnv.innerWidth, gameEnv.innerHeight, and gameEnv.stats.</pre>
</details>

<details class="details-folder"><summary>API Integration</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('api-integration-files')">Files</button>
<button onclick="toggleSnippet('api-integration-locations')">Locations</button>
<button onclick="toggleSnippet('api-integration-implementation')">Implementation</button>
</div>
<pre id="api-integration-files" class="code-snippet">astromusic.js
astroplatformer.js</pre>
<pre id="api-integration-locations" class="code-snippet">_projects/games/astronaut-platformer-game/levels/astromusic.js
_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
<pre id="api-integration-implementation" class="code-snippet">fetch(url) to iTunes API and Leaderboard.submitScore(...) in platformer.</pre>
</details>

<details class="details-folder"><summary>Asynchronous I/O</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('async-io-files')">Files</button>
<button onclick="toggleSnippet('async-io-locations')">Locations</button>
<button onclick="toggleSnippet('async-io-implementation')">Implementation</button>
</div>
<pre id="async-io-files" class="code-snippet">astromusic.js</pre>
<pre id="async-io-locations" class="code-snippet">_projects/games/astronaut-platformer-game/levels/astromusic.js</pre>
<pre id="async-io-implementation" class="code-snippet">async fetchPreviewUrl() and await response.json() show async flow.</pre>
</details>

<details class="details-folder"><summary>JSON Parsing</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('json-parsing-files')">Files</button>
<button onclick="toggleSnippet('json-parsing-locations')">Locations</button>
<button onclick="toggleSnippet('json-parsing-implementation')">Implementation</button>
</div>
<pre id="json-parsing-files" class="code-snippet">astromusic.js</pre>
<pre id="json-parsing-locations" class="code-snippet">_projects/games/astronaut-platformer-game/levels/astromusic.js</pre>
<pre id="json-parsing-implementation" class="code-snippet">Parses API response with await response.json().</pre>
</details>

<details class="details-folder"><summary>Code Comments</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('code-comments-files')">Files</button>
<button onclick="toggleSnippet('code-comments-locations')">Locations</button>
<button onclick="toggleSnippet('code-comments-implementation')">Implementation</button>
</div>
<pre id="code-comments-files" class="code-snippet">astroplatformer.js</pre>
<pre id="code-comments-locations" class="code-snippet">_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
<pre id="code-comments-implementation" class="code-snippet">Extensive inline comments document physics, collision, and level setup.</pre>
</details>

<details class="details-folder"><summary>Documentation</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('documentation-files')">Files</button>
<button onclick="toggleSnippet('documentation-locations')">Locations</button>
<button onclick="toggleSnippet('documentation-implementation')">Implementation</button>
</div>
<pre id="documentation-files" class="code-snippet">ASTROGRAVBLOG.md</pre>
<pre id="documentation-locations" class="code-snippet">_projects/games/astronaut-platformer-game/ASTROGRAVBLOG.md</pre>
<pre id="documentation-implementation" class="code-snippet">Game setup and narrative notes are documented in the level page.</pre>
</details>

<details class="details-folder"><summary>Console Debugging</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('console-debugging-files')">Files</button>
<button onclick="toggleSnippet('console-debugging-locations')">Locations</button>
<button onclick="toggleSnippet('console-debugging-implementation')">Implementation</button>
</div>
<pre id="console-debugging-files" class="code-snippet">astromusic.js</pre>
<pre id="console-debugging-locations" class="code-snippet">_projects/games/astronaut-platformer-game/levels/astromusic.js</pre>
<pre id="console-debugging-implementation" class="code-snippet">console.log and console.warn trace API and music start behavior.</pre>
</details>

<details class="details-folder"><summary>Hit Box Visualization</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('hitbox-visualization-files')">Files</button>
<button onclick="toggleSnippet('hitbox-visualization-locations')">Locations</button>
<button onclick="toggleSnippet('hitbox-visualization-implementation')">Implementation</button>
</div>
<pre id="hitbox-visualization-files" class="code-snippet">astroplatformer.js</pre>
<pre id="hitbox-visualization-locations" class="code-snippet">_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
<pre id="hitbox-visualization-implementation" class="code-snippet">Hitbox values and collision boundary checks are computed and explained in comments.</pre>
</details>

<details class="details-folder"><summary>Gameplay Testing</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('gameplay-testing-files')">Files</button>
<button onclick="toggleSnippet('gameplay-testing-locations')">Locations</button>
<button onclick="toggleSnippet('gameplay-testing-implementation')">Implementation</button>
</div>
<pre id="gameplay-testing-files" class="code-snippet">astroplatformer.js</pre>
<pre id="gameplay-testing-locations" class="code-snippet">_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
<pre id="gameplay-testing-implementation" class="code-snippet">Full playable level with movement, coins, win condition, and death flow.</pre>
</details>

<details class="details-folder"><summary>Integration Testing</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('integration-testing-files')">Files</button>
<button onclick="toggleSnippet('integration-testing-locations')">Locations</button>
<button onclick="toggleSnippet('integration-testing-implementation')">Implementation</button>
</div>
<pre id="integration-testing-files" class="code-snippet">astromusic.js
astroplatformer.js</pre>
<pre id="integration-testing-locations" class="code-snippet">_projects/games/astronaut-platformer-game/levels/astromusic.js
_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
<pre id="integration-testing-implementation" class="code-snippet">API fetch and leaderboard submission show real integration points.</pre>
</details>

<details class="details-folder"><summary>API Error Handling</summary>
<div class="topic-buttons">
<button onclick="toggleSnippet('api-error-handling-files')">Files</button>
<button onclick="toggleSnippet('api-error-handling-locations')">Locations</button>
<button onclick="toggleSnippet('api-error-handling-implementation')">Implementation</button>
</div>
<pre id="api-error-handling-files" class="code-snippet">astromusic.js</pre>
<pre id="api-error-handling-locations" class="code-snippet">_projects/games/astronaut-platformer-game/levels/astromusic.js</pre>
<pre id="api-error-handling-implementation" class="code-snippet">try/catch around fetch and JSON parsing handles API failures.</pre>
</details>
