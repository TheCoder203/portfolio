# %% [markdown]
# ---
# layout: post
# title: Table of Completion
# description: table
# categories: [Javascript, Homework]
# permalink: /table
# author: Krish K
# ---

# %% [markdown]
# ## College Ready
#
# <style>
# /* Main category styling */
# .details-folder {
#   margin: 1.2em 0;
#   padding: 1.1em;
#   border: 2px solid transparent;
#   border-radius: 12px;
#   background: linear-gradient(135deg, #ffffff 0%, #f8f9ff 100%);
#   box-shadow: 0 4px 15px rgba(0, 0, 0, 0.08);
#   transition: all 0.3s ease;
# }
#
# .details-folder:hover {
#   box-shadow: 0 8px 25px rgba(0, 0, 0, 0.12);
#   transform: translateY(-2px);
# }
#
# /* Category colors */
# .details-folder:nth-of-type(1) { border-color: #FF6B6B; background: linear-gradient(135deg, #FFE5E5 0%, #ffffff 100%); }
# .details-folder:nth-of-type(2) { border-color: #4ECDC4; background: linear-gradient(135deg, #E0F7F6 0%, #ffffff 100%); }
# .details-folder:nth-of-type(3) { border-color: #FFD93D; background: linear-gradient(135deg, #FFFBE6 0%, #ffffff 100%); }
# .details-folder:nth-of-type(4) { border-color: #6BCF7F; background: linear-gradient(135deg, #E8F8ED 0%, #ffffff 100%); }
# .details-folder:nth-of-type(5) { border-color: #A78BFA; background: linear-gradient(135deg, #F3F0FF 0%, #ffffff 100%); }
# .details-folder:nth-of-type(6) { border-color: #F97316; background: linear-gradient(135deg, #FEF3E2 0%, #ffffff 100%); }
# .details-folder:nth-of-type(7) { border-color: #EC4899; background: linear-gradient(135deg, #FCE7F3 0%, #ffffff 100%); }
# .details-folder:nth-of-type(8) { border-color: #06B6D4; background: linear-gradient(135deg, #E0F7FA 0%, #ffffff 100%); }
#
# .details-folder summary {
#   color: #1a1a1a;
#   font-weight: 800;
#   font-size: 1.05em;
#   cursor: pointer;
#   outline: none;
#   padding: 0.5em;
#   margin: -0.5em;
#   border-radius: 8px;
#   transition: all 0.2s ease;
# }
#
# .details-folder summary:hover {
#   background-color: rgba(0, 0, 0, 0.03);
#   transform: translateX(4px);
# }
#
# /* Topic page links */
# .topic-page-link {
#   text-decoration: none;
#   display: inline-block;
#   margin-top: 0.8em;
# }
#
# .topic-page-link div {
#   background: linear-gradient(135deg, #3884ff 0%, #2563eb 100%);
#   color: white;
#   padding: 10px 16px;
#   border-radius: 8px;
#   font-weight: 700;
#   display: inline-block;
#   box-shadow: 0 4px 12px rgba(56, 132, 255, 0.3);
#   transition: all 0.3s ease;
#   cursor: pointer;
#   border: 2px solid transparent;
# }
#
# .topic-page-link div:hover {
#   transform: translateY(-3px);
#   box-shadow: 0 6px 20px rgba(56, 132, 255, 0.4);
#   background: linear-gradient(135deg, #2563eb 0%, #1d4ed8 100%);
# }
#
# .topic-page-link div:active {
#   transform: translateY(-1px);
# }
#
# h2 {
#   color: #1a1a2e;
#   font-weight: 900;
#   font-size: 2em;
#   margin: 1.5em 0 1em 0;
# }
# </style>
#
# <!-- OOP -->
# <details class="details-folder">
#   <summary>OOP</summary>
#
#   <details class="details-folder">
#     <summary>Writing Classes</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/writing-classes">
#       <div>Open Writing Classes Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>Methods & Parameters</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/methods-parameters">
#       <div>Open Methods & Parameters Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>Instantiation & Objects</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/instantiation-objects">
#       <div>Open Instantiation & Objects Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>Inheritance (Basic)</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/inheritance-basic">
#       <div>Open Inheritance (Basic) Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>Method Overriding</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/method-overriding">
#       <div>Open Method Overriding Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>Constructor Chaining</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/constructor-chaining">
#       <div>Open Constructor Chaining Page</div>
#     </a>
#   </details>
# </details>
#
# <!-- Control Structures -->
# <details class="details-folder">
#   <summary>Control Structures</summary>
#
#   <details class="details-folder">
#     <summary>Iteration</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/iteration">
#       <div>Open Iteration Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>Conditionals</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/conditionals">
#       <div>Open Conditionals Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>Nested Conditions</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/nested-conditions">
#       <div>Open Nested Conditions Page</div>
#     </a>
#   </details>
# </details>
#
# <!-- Data Types -->
# <details class="details-folder">
#   <summary>Data Types</summary>
#
#   <details class="details-folder">
#     <summary>Numbers</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/numbers">
#       <div>Open Numbers Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>Strings</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/strings">
#       <div>Open Strings Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>Booleans</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/booleans">
#       <div>Open Booleans Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>Arrays</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/arrays">
#       <div>Open Arrays Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>Objects (JSON)</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/objects-json">
#       <div>Open Objects (JSON) Page</div>
#     </a>
#   </details>
# </details>
#
# <!-- Operators -->
# <details class="details-folder">
#   <summary>Operators</summary>
#
#   <details class="details-folder">
#     <summary>Mathematical Operators</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/mathematical-operators">
#       <div>Open Mathematical Operators Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>String Operations</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/string-operations">
#       <div>Open String Operations Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>Boolean Expressions</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/boolean-expressions">
#       <div>Open Boolean Expressions Page</div>
#     </a>
#   </details>
# </details>
#
# <!-- Input/Output -->
# <details class="details-folder">
#   <summary>Input/Output</summary>
#
#   <details class="details-folder">
#     <summary>Keyboard Input</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/keyboard-input">
#       <div>Open Keyboard Input Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>Canvas Rendering</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/canvas-rendering">
#       <div>Open Canvas Rendering Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>GameEnv Configuration</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/gameenv-configuration">
#       <div>Open GameEnv Configuration Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>API Integration</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/api-integration">
#       <div>Open API Integration Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>Asynchronous I/O</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/asynchronous-io">
#       <div>Open Asynchronous I/O Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>JSON Parsing</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/json-parsing">
#       <div>Open JSON Parsing Page</div>
#     </a>
#   </details>
# </details>
#
# <!-- Documentation -->
# <details class="details-folder">
#   <summary>Documentation</summary>
#
#   <details class="details-folder">
#     <summary>Code Comments</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/code-comments">
#       <div>Open Code Comments Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>Documentation</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/documentation">
#       <div>Open Documentation Page</div>
#     </a>
#   </details>
# </details>
#
# <!-- Debugging -->
# <details class="details-folder">
#   <summary>Debugging</summary>
#
#   <details class="details-folder">
#     <summary>Console Debugging</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/console-debugging">
#       <div>Open Console Debugging Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>Hit Box Visualization</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/hit-box-visualization">
#       <div>Open Hit Box Visualization Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>Source-Level Debugging</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/source-level-debugging">
#       <div>Open Source-Level Debugging Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>Network Debugging</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/network-debugging">
#       <div>Open Network Debugging Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>Application Debugging</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/application-debugging">
#       <div>Open Application Debugging Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>Element Inspection</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/element-inspection">
#       <div>Open Element Inspection Page</div>
#     </a>
#   </details>
# </details>
#
# <!-- Testing & Verification -->
# <details class="details-folder">
#   <summary>Testing & Verification</summary>
#
#   <details class="details-folder">
#     <summary>Gameplay Testing</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/gameplay-testing">
#       <div>Open Gameplay Testing Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>Integration Testing</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/integration-testing">
#       <div>Open Integration Testing Page</div>
#     </a>
#   </details>
#
#   <details class="details-folder">
#     <summary>API Error Handling</summary>
#     <a class="topic-page-link" href="{{site.baseurl}}/api-error-handling">
#       <div>Open API Error Handling Page</div>
#     </a>
#   </details>
# </details>
