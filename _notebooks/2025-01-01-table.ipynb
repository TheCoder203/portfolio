# %% [markdown]
# ---
# layout: post
# title: Table of Completion
# description: table
# categories: [Javascript, Homework]
# permalink: /table
# author: Krish K
# ---

# %% [markdown]
# ## College Ready
#
# <style>
# /* Category color map - rotating vibrant colors */
# .details-folder {
#   margin: 1.2em 0;
#   padding: 1.1em;
#   border: 2px solid transparent;
#   border-radius: 12px;
#   background: linear-gradient(135deg, #ffffff 0%, #f8f9ff 100%);
#   box-shadow: 0 4px 15px rgba(0, 0, 0, 0.08);
#   transition: all 0.3s ease;
# }
#
# .details-folder:hover {
#   box-shadow: 0 8px 25px rgba(0, 0, 0, 0.12);
#   transform: translateY(-2px);
# }
#
# /* Category colors - cycling through vibrant palette */
# .details-folder:nth-of-type(1) { border-color: #FF6B6B; background: linear-gradient(135deg, #FFE5E5 0%, #ffffff 100%); }
# .details-folder:nth-of-type(2) { border-color: #4ECDC4; background: linear-gradient(135deg, #E0F7F6 0%, #ffffff 100%); }
# .details-folder:nth-of-type(3) { border-color: #FFD93D; background: linear-gradient(135deg, #FFFBE6 0%, #ffffff 100%); }
# .details-folder:nth-of-type(4) { border-color: #6BCF7F; background: linear-gradient(135deg, #E8F8ED 0%, #ffffff 100%); }
# .details-folder:nth-of-type(5) { border-color: #A78BFA; background: linear-gradient(135deg, #F3F0FF 0%, #ffffff 100%); }
# .details-folder:nth-of-type(6) { border-color: #F97316; background: linear-gradient(135deg, #FEF3E2 0%, #ffffff 100%); }
# .details-folder:nth-of-type(7) { border-color: #EC4899; background: linear-gradient(135deg, #FCE7F3 0%, #ffffff 100%); }
# .details-folder:nth-of-type(8) { border-color: #06B6D4; background: linear-gradient(135deg, #E0F7FA 0%, #ffffff 100%); }
#
# .details-folder summary {
#   color: #1a1a1a;
#   font-weight: 800;
#   font-size: 1.05em;
#   cursor: pointer;
#   outline: none;
#   padding: 0.5em;
#   margin: -0.5em;
#   border-radius: 8px;
#   transition: all 0.2s ease;
# }
#
# .details-folder summary:hover {
#   background-color: rgba(0, 0, 0, 0.03);
#   transform: translateX(4px);
# }
#
# .details-folder details {
#   margin: 0.8em 0 0 1.2em;
#   padding: 0.8em 1em;
#   border-left: 4px solid;
#   background: #ffffff;
#   border-radius: 8px;
#   box-shadow: inset 0 2px 6px rgba(0, 0, 0, 0.03);
#   transition: all 0.2s ease;
# }
#
# .details-folder details:hover {
#   background: #fafafe;
# }
#
# /* Subcategory border colors */
# .details-folder:nth-of-type(1) details { border-left-color: #FF6B6B; }
# .details-folder:nth-of-type(2) details { border-left-color: #4ECDC4; }
# .details-folder:nth-of-type(3) details { border-left-color: #FFD93D; }
# .details-folder:nth-of-type(4) details { border-left-color: #6BCF7F; }
# .details-folder:nth-of-type(5) details { border-left-color: #A78BFA; }
# .details-folder:nth-of-type(6) details { border-left-color: #F97316; }
# .details-folder:nth-of-type(7) details { border-left-color: #EC4899; }
# .details-folder:nth-of-type(8) details { border-left-color: #06B6D4; }
#
# .details-folder details summary {
#   color: #333;
#   font-weight: 700;
#   font-size: 0.95em;
#   padding: 0.4em 0.6em;
#   border-radius: 6px;
# }
#
# .details-folder details summary:hover {
#   background-color: rgba(0, 0, 0, 0.04);
# }
#
# /* Code blocks - sleek dark theme */
# .details-folder pre {
#   margin: 0.6em 0 0 0;
#   padding: 0.9em 1.1em;
#   background: linear-gradient(135deg, #1e1e2e 0%, #2a2a3e 100%);
#   color: #e0e0e0;
#   border-radius: 8px;
#   border-left: 3px solid;
#   white-space: pre-wrap;
#   font-family: 'Monaco', 'Courier New', monospace;
#   font-size: 0.9em;
#   line-height: 1.5;
#   box-shadow: 0 2px 8px rgba(0, 0, 0, 0.2);
# }
#
# .details-folder:nth-of-type(1) pre { border-left-color: #FF6B6B; }
# .details-folder:nth-of-type(2) pre { border-left-color: #4ECDC4; }
# .details-folder:nth-of-type(3) pre { border-left-color: #FFD93D; }
# .details-folder:nth-of-type(4) pre { border-left-color: #6BCF7F; }
# .details-folder:nth-of-type(5) pre { border-left-color: #A78BFA; }
# .details-folder:nth-of-type(6) pre { border-left-color: #F97316; }
# .details-folder:nth-of-type(7) pre { border-left-color: #EC4899; }
# .details-folder:nth-of-type(8) pre { border-left-color: #06B6D4; }
#
# /* Topic page links */
# .topic-page-link {
#   text-decoration: none;
#   display: inline-block;
#   margin-top: 0.6em;
# }
#
# .topic-page-link div {
#   background: linear-gradient(135deg, #3884ff 0%, #2563eb 100%);
#   color: white;
#   padding: 10px 16px;
#   border-radius: 8px;
#   font-weight: 700;
#   display: inline-block;
#   box-shadow: 0 4px 12px rgba(56, 132, 255, 0.3);
#   transition: all 0.3s ease;
#   cursor: pointer;
#   border: 2px solid transparent;
# }
#
# .topic-page-link div:hover {
#   transform: translateY(-3px);
#   box-shadow: 0 6px 20px rgba(56, 132, 255, 0.4);
#   background: linear-gradient(135deg, #2563eb 0%, #1d4ed8 100%);
# }
#
# .topic-page-link div:active {
#   transform: translateY(-1px);
# }
#
# /* Overall container styling */
# h2 {
#   color: #1a1a2e;
#   font-weight: 900;
#   font-size: 2em;
#   margin: 1.5em 0 1em 0;
#   text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.05);
# }
# </style>
#
# <details class="details-folder"><summary>OOP</summary>
#   <details class="details-folder"><summary>Writing Classes</summary>
#     <details><summary>Files</summary>
#       <pre>allhw.ipynb
# astroplatformer.js
# astromusic.js
# astrodeath.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_notebooks/2026-5-13-allhw.ipynb
# _projects/games/astronaut-platformer-game/levels/astroplatformer.js
# _projects/games/astronaut-platformer-game/levels/astromusic.js
# _projects/games/astronaut-platformer-game/levels/astrodeath.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>Defines multiple classes in notebook examples and game level classes in platformer, music, and death levels.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/writing-classes"><div>Open Writing Classes Page</div></a>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>Methods & Parameters</summary>
#     <details><summary>Files</summary>
#       <pre>allhw.ipynb
# astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_notebooks/2026-5-13-allhw.ipynb
# _projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>Functions with parameters like Login(_username, _password), scaleCoin(source, sx, sy), and _die(reason) manage behavior and state.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/methods-parameters"><div>Open Methods & Parameters Page</div></a>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>Instantiation & Objects</summary>
#     <details><summary>Files</summary>
#       <pre>astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>this.classes = [...] registers game objects; new Leaderboard(...) and gameEnv.stats instantiate runtime objects.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/instantiation-objects"><div>Open Instantiation & Objects Page</div></a>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>Inheritance (Basic)</summary>
#     <details><summary>Files</summary>
#       <pre>allhw.ipynb
# astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_notebooks/2026-5-13-allhw.ipynb
# _projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>class ElectricCar extends Car and class FixedPlatformerCoin extends Coin show subclassing.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/inheritance-basic"><div>Open Inheritance (Basic) Page</div></a>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>Method Overriding</summary>
#     <details><summary>Files</summary>
#       <pre>astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>Overrides update() and collect() in FixedPlatformerCoin to customize coin behavior.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/method-overriding"><div>Open Method Overriding Page</div></a>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>Constructor Chaining</summary>
#     <details><summary>Files</summary>
#       <pre>allhw.ipynb</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_notebooks/2026-5-13-allhw.ipynb</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>super(make, model, fuel) in ElectricCar demonstrates chaining parent constructors.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/constructor-chaining"><div>Open Constructor Chaining Page</div></a>
#     </details>
#   </details>
# </details><details class="details-folder"><summary>Control Structures</summary>
#   <details class="details-folder"><summary>Iteration</summary>
#     <details><summary>Files</summary>
#       <pre>allhw.ipynb
# astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_notebooks/2026-5-13-allhw.ipynb
# _projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>Uses for...of, while, and .map() to loop through arrays of objects and game logic.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/iteration"><div>Open Iteration Page</div></a>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>Conditionals</summary>
#     <details><summary>Files</summary>
#       <pre>astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>Many if/else if/else branches handle physics, collisions, player death, and win conditions.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/conditionals"><div>Open Conditionals Page</div></a>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>Nested Conditions</summary>
#     <details><summary>Files</summary>
#       <pre>astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>Nested collision logic is used for platform top, ceiling, and wall detection.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/nested-conditions"><div>Open Nested Conditions Page</div></a>
#     </details>
#   </details>
# </details><details class="details-folder"><summary>Data Types</summary>
#   <details class="details-folder"><summary>Numbers</summary>
#     <details><summary>Files</summary>
#       <pre>astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>Numeric properties for position, velocity, scale, coins, lives, and physics calculations.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/numbers"><div>Open Numbers Page</div></a>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>Strings</summary>
#     <details><summary>Files</summary>
#       <pre>astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>File paths, HUD text, template literals, and status messages.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/strings"><div>Open Strings Page</div></a>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>Booleans</summary>
#     <details><summary>Files</summary>
#       <pre>astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>Flags like _isDead, _won, keys.w, collected, and userActivated.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/booleans"><div>Open Booleans Page</div></a>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>Arrays</summary>
#     <details><summary>Files</summary>
#       <pre>astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>Arrays for _platforms, _spikes, _coinPositions, and keyboard state.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/arrays"><div>Open Arrays Page</div></a>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>Objects (JSON)</summary>
#     <details><summary>Files</summary>
#       <pre>astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>playerData, baseLayout, coinData, and scaled platform objects.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/objects-json"><div>Open Objects (JSON) Page</div></a>
#     </details>
#   </details>
# </details><details class="details-folder"><summary>Operators</summary>
#   <details class="details-folder"><summary>Mathematical Operators</summary>
#     <details><summary>Files</summary>
#       <pre>astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>Uses +, -, *, /, and Math.min for movement, gravity, and collision math.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/mathematical-operators"><div>Open Mathematical Operators Page</div></a>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>String Operations</summary>
#     <details><summary>Files</summary>
#       <pre>astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>Path concatenation and template literal generation for UI and assets.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/string-operations"><div>Open String Operations Page</div></a>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>Boolean Expressions</summary>
#     <details><summary>Files</summary>
#       <pre>astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>Compound conditions for collision detection and input handling.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/boolean-expressions"><div>Open Boolean Expressions Page</div></a>
#     </details>
#   </details>
# </details><details class="details-folder"><summary>Input/Output</summary>
#   <details class="details-folder"><summary>Keyboard Input</summary>
#     <details><summary>Files</summary>
#       <pre>astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>document.addEventListener('keydown', this._keyDown) and keyup handle WASD/arrow input.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/keyboard-input"><div>Open Keyboard Input Page</div></a>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>Canvas Rendering</summary>
#     <details><summary>Files</summary>
#       <pre>astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>Sets up game object classes and overlay DOM elements for rendering via the game engine.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/canvas-rendering"><div>Open Canvas Rendering Page</div></a>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>GameEnv Configuration</summary>
#     <details><summary>Files</summary>
#       <pre>astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>Uses gameEnv.path, gameEnv.innerWidth, gameEnv.innerHeight, and gameEnv.stats.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/gameenv-configuration"><div>Open GameEnv Configuration Page</div></a>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>API Integration</summary>
#     <details><summary>Files</summary>
#       <pre>astromusic.js
# astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astromusic.js
# _projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>fetch(url) to iTunes API and Leaderboard.submitScore(...) in platformer.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/api-integration"><div>Open API Integration Page</div></a>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>Asynchronous I/O</summary>
#     <details><summary>Files</summary>
#       <pre>astromusic.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astromusic.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>async fetchPreviewUrl() and await response.json() show async flow.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/asynchronous-io"><div>Open Asynchronous I/O Page</div></a>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>JSON Parsing</summary>
#     <details><summary>Files</summary>
#       <pre>astromusic.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astromusic.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>Parses API response with await response.json().</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/json-parsing"><div>Open JSON Parsing Page</div></a>
#     </details>
#   </details>
# </details><details class="details-folder"><summary>Documentation</summary>
#   <details class="details-folder"><summary>Code Comments</summary>
#     <details><summary>Files</summary>
#       <pre>astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>Extensive inline comments document physics, collision, and level setup.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/code-comments"><div>Open Code Comments Page</div></a>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>Documentation</summary>
#     <details><summary>Files</summary>
#       <pre>ASTROGRAVBLOG.md</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/ASTROGRAVBLOG.md</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>Game setup and narrative notes are documented in the level page.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/documentation"><div>Open Documentation Page</div></a>
#     </details>
#   </details>
# </details><details class="details-folder"><summary>Debugging</summary>
#   <details class="details-folder"><summary>Console Debugging</summary>
#     <details><summary>Files</summary>
#       <pre>astromusic.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astromusic.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>Use console.log to track game state, variables, and method calls.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/console-debugging"><div>Open Console Debugging Page</div></a>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>Hit Box Visualization</summary>
#     <details><summary>Files</summary>
#       <pre>astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>Draw and visualize collision boundaries to refine detection.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/hit-box-visualization"><div>Open Hit Box Visualization Page</div></a>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>Source-Level Debugging</summary>
#     <details><summary>Files</summary>
#       <pre>astromusic.js
# astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astromusic.js
# _projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>Set breakpoints in DevTools and step through code execution.</pre>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>Network Debugging</summary>
#     <details><summary>Files</summary>
#       <pre>astromusic.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astromusic.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>Inspect fetch requests, response data, and error messages in the Network tab.</pre>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>Application Debugging</summary>
#     <details><summary>Files</summary>
#       <pre>astromusic.js
# astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astromusic.js
# _projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>Inspect cookies, localStorage, and session data in DevTools Application panel.</pre>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>Element Inspection</summary>
#     <details><summary>Files</summary>
#       <pre>astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>Inspect DOM elements, styles, and event listeners using the Elements panel.</pre>
#     </details>
#   </details>
# </details><details class="details-folder"><summary>Testing & Verification</summary>
#   <details class="details-folder"><summary>Gameplay Testing</summary>
#     <details><summary>Files</summary>
#       <pre>astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>Full playable level with movement, coins, win condition, and death flow.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/gameplay-testing"><div>Open Gameplay Testing Page</div></a>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>Integration Testing</summary>
#     <details><summary>Files</summary>
#       <pre>astromusic.js
# astroplatformer.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astromusic.js
# _projects/games/astronaut-platformer-game/levels/astroplatformer.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>API fetch and leaderboard submission show real integration points.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/integration-testing"><div>Open Integration Testing Page</div></a>
#     </details>
#   </details>
#
#   <details class="details-folder"><summary>API Error Handling</summary>
#     <details><summary>Files</summary>
#       <pre>astromusic.js</pre>
#     </details>
#     <details><summary>Locations</summary>
#       <pre>_projects/games/astronaut-platformer-game/levels/astromusic.js</pre>
#     </details>
#     <details><summary>Implementation</summary>
#       <pre>try/catch around fetch and JSON parsing handles API failures.</pre>
#     </details>
#     <details><summary>Topic Page</summary>
#       <a class="topic-page-link" href="{{site.baseurl}}/api-error-handling"><div>Open API Error Handling Page</div></a>
#     </details>
#   </details>
# </details>
