# %% [markdown]
# ---
# layout: post
# title: All Homeworks
# description: All Homeworks
# categories: [Javascript, Homework]
# permalink: /table
# author: Krish K
# ---

# %% [markdown]
# ## Assessment Evidence Table
#
# | Learning Objective | Where to find it | How it's implemented |
# | --- | --- | --- |
# | Writing Classes | `_notebooks/2026-5-13-allhw.ipynb`, `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, `_projects/games/astronaut-platformer-game/levels/astromusic.js`, `_projects/games/astronaut-platformer-game/levels/astrodeath.js` | Defines multiple classes in notebook examples and game level classes in platformer and music levels. |
# | Methods & Parameters | `_notebooks/2026-5-13-allhw.ipynb`, `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Functions with parameters like `Login(_username, _password)`, `scaleCoin(source, sx, sy)`, and `_die(reason)` manage behavior and state. |
# | Instantiation & Objects | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | `this.classes = [...]` registers game objects; `new Leaderboard(...)` and `gameEnv.stats` instantiate runtime objects. |
# | Inheritance (Basic) | `_notebooks/2026-5-13-allhw.ipynb`, `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | `class ElectricCar extends Car` and `class FixedPlatformerCoin extends Coin` show subclassing. |
# | Method Overriding | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Overrides `update()` and `collect()` in `FixedPlatformerCoin` to customize coin behavior. |
# | Constructor Chaining | `_notebooks/2026-5-13-allhw.ipynb` | `super(make, model, fuel)` in `ElectricCar` demonstrates chaining parent constructors. |
# | Iteration | `_notebooks/2026-5-13-allhw.ipynb`, `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Uses `for...of`, `while`, and `.map()` to loop through arrays of objects and game logic. |
# | Conditionals | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Many `if/else if/else` branches handle physics, collisions, player death, and win conditions. |
# | Nested Conditions | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Nested collision logic is used for platform top, ceiling, and wall detection. |
# | Numbers | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Numeric properties for position, velocity, scale, coins, lives, and physics calculations. |
# | Strings | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | File paths, HUD text, template literals, and status messages. |
# | Booleans | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Flags like `_isDead`, `_won`, `keys.w`, `collected`, and `userActivated`. |
# | Arrays | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Arrays for `_platforms`, `_spikes`, `_coinPositions`, and keyboard state. |
# | Objects (JSON) | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | `playerData`, `baseLayout`, `coinData`, and scaled platform objects. |
# | Mathematical Operators | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Uses `+`, `-`, `*`, `/`, and `Math.min` for movement, gravity, and collision math. |
# | String Operations | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Path concatenation and template literal generation for UI and assets. |
# | Boolean Expressions | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Compound conditions for collision detection and input handling. |
# | Keyboard Input | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | `document.addEventListener('keydown', this._keyDown)` and `keyup` handle WASD/arrow input. |
# | Canvas Rendering | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Sets up game object classes and overlay DOM elements for rendering via the game engine. |
# | GameEnv Configuration | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Uses `gameEnv.path`, `gameEnv.innerWidth`, `gameEnv.innerHeight`, and `gameEnv.stats`. |
# | API Integration | `_projects/games/astronaut-platformer-game/levels/astromusic.js` | `fetch(url)` to iTunes API and `Leaderboard.submitScore(...)` in platformer. |
# | Asynchronous I/O | `_projects/games/astronaut-platformer-game/levels/astromusic.js` | `async fetchPreviewUrl()` and `await response.json()` show async flow. |
# | JSON Parsing | `_projects/games/astronaut-platformer-game/levels/astromusic.js` | Parses API response with `await response.json()`. |
# | Code Comments | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Extensive inline comments document physics, collision, and level setup. |
# | Documentation | `_projects/games/astronaut-platformer-game/01-v1-astronaut-platformer-game.md` | Game setup and narrative notes are documented in the level page. |
# | Console Debugging | `_projects/games/astronaut-platformer-game/levels/astromusic.js` | `console.log` and `console.warn` trace API and music start behavior. |
# | Hit Box Visualization | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Hitbox values and collision boundary checks are computed and explained in comments. |
# | Gameplay Testing | `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | Full playable level with movement, coins, win condition, and death flow. |
# | Integration Testing | `_projects/games/astronaut-platformer-game/levels/astromusic.js`, `_projects/games/astronaut-platformer-game/levels/astroplatformer.js` | API fetch and leaderboard submission show real integration points. |
# | API Error Handling | `_projects/games/astronaut-platformer-game/levels/astromusic.js` | `try/catch` around fetch and JSON parsing handles API failures. |
