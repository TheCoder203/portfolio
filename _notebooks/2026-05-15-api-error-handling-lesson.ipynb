// %% [markdown]
// ---
// layout: post
// title: Api Error Handling
// description: Lesson for api-error-handling
// categories: [Javascript, Lesson]
// permalink: /api-error-handling-lesson
// author: Krish K
// codemirror: true
// ---

// %% [markdown]
// ## Api Error Handling
//
// Learning from AstroPlatformer

// %%
%%js
// CODE_RUNNER: api-error-handling

try {
  const x = JSON.parse("invalid");
} catch(e) {
  console.log("Caught error:", e.message);
}
try {
  const s = localStorage.getItem("test");
  console.log("Storage ok");
} catch(e) {
  console.log("Storage error:", e);
}
