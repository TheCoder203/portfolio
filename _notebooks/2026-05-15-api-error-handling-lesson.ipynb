// %%
---layout: posttitle: API Error Handlingdescription: Error handling - try/catch for errorscategories: [Javascript, Lesson]permalink: /api-error-handling-lessonauthor: Krish Kcodemirror: true---

// %% [markdown]
// ## API Error Handling
//
// Learning from AstroPlatformer

// %%
%%js
try {
  const x = JSON.parse("invalid");
} catch(e) {
  console.log("Caught error:", e.message);
}
try {
  const s = localStorage.getItem("test");
  console.log("Storage ok");
} catch(e) {
  console.log("Storage error:", e);
}
