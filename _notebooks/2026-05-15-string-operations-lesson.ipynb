// %%
---layout: posttitle: String Operationsdescription: String methods - manipulating stringscategories: [Javascript, Lesson]permalink: /string-operations-lessonauthor: Krish Kcodemirror: true---

// %% [markdown]
// ## String Operations
//
// Learning from AstroPlatformer

// %%
%%js
let msg = "AstroPlatformer";
console.log("Length:", msg.length);
console.log("Upper:", msg.toUpperCase());
const part = "Level" + " 1";
console.log(msg.includes("Astro") ? "Contains Astro" : "No");
