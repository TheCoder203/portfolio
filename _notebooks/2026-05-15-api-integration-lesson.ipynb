// %%
---layout: posttitle: API Integrationdescription: APIs - integrating external servicescategories: [Javascript, Lesson]permalink: /api-integration-lessonauthor: Krish Kcodemirror: true---

// %% [markdown]
// ## API Integration
//
// Learning from AstroPlatformer

// %%
%%js
function getScores() {
  return new Promise(r => setTimeout(() => r([{name:"Player",score:100}]), 100));
}
getScores().then(s => console.log("Scores:", s));
