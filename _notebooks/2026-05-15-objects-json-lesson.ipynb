// %%
---layout: posttitle: Objects and JSONdescription: Objects - working with object propertiescategories: [Javascript, Lesson]permalink: /objects-json-lessonauthor: Krish Kcodemirror: true---

// %% [markdown]
// ## Objects and JSON
//
// Learning from AstroPlatformer

// %%
%%js
const platform = {id:"p1",x:40,y:290,width:120,color:"#4a9eff"};
console.log("Platform:", platform.id);
console.log("Size:", platform.width);
platform.visited = true;
console.log("Updated:", platform);
