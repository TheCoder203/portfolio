// %% [markdown]
// ---
// layout: post
// title: Instantiation Objects
// description: Lesson for instantiation-objects
// categories: [Javascript, Lesson]
// permalink: /instantiation-objects-lesson
// author: Krish K
// codemirror: true
// ---

// %% [markdown]
// ## Instantiation Objects
//
// Learning from AstroPlatformer

// %%
%%js
// CODE_RUNNER: instantiation-objects

const p = new Object();
p.id = "p1"; p.x = 40;
const c = {id: "c1", x: 90};
console.log(p, c);
