// %%
---layout: posttitle: Object Instantiationdescription: new keyword - creating object instancescategories: [Javascript, Lesson]permalink: /instantiation-objects-lessonauthor: Krish Kcodemirror: true---

// %% [markdown]
// ## Object Instantiation
//
// Learning from AstroPlatformer

// %%
%%js
const p = new Object();
p.id = "p1"; p.x = 40;
const c = {id: "c1", x: 90};
console.log(p, c);
