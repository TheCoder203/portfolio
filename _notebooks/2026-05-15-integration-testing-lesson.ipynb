// %% [markdown]
// ---
// layout: post
// title: Integration Testing
// description: Lesson for integration-testing
// categories: [Javascript, Lesson]
// permalink: /integration-testing-lesson
// author: Krish K
// codemirror: true
// ---

// %% [markdown]
// ## Integration Testing
//
// Learning from AstroPlatformer

// %%
%%js
// CODE_RUNNER: integration-testing

const game = {platforms: [{id:"p1"}], coins: [], player: {x:30}};
console.log("Platforms:", game.platforms.length);
console.log("Coins:", game.coins.length);
