// %%
---layout: posttitle: Integration Testingdescription: Integration tests - testing system componentscategories: [Javascript, Lesson]permalink: /integration-testing-lessonauthor: Krish Kcodemirror: true---

// %% [markdown]
// ## Integration Testing
//
// Learning from AstroPlatformer

// %%
%%js
const game = {platforms: [{id:"p1"}], coins: [], player: {x:30}};
console.log("Platforms:", game.platforms.length);
console.log("Coins:", game.coins.length);
