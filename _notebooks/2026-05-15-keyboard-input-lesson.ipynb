// %% [markdown]
// ---
// layout: post
// title: Keyboard Input
// description: Lesson for keyboard-input
// categories: [Javascript, Lesson]
// permalink: /keyboard-input-lesson
// author: Krish K
// codemirror: true
// ---

// %% [markdown]
// ## Keyboard Input
//
// Learning from AstroPlatformer

// %%
%%js
// CODE_RUNNER: keyboard-input

const keys = {w:false, a:false};
function keyDown(e) {if(e.key==="w") keys.w=true;}
function keyUp(e) {if(e.key==="w") keys.w=false;}
console.log("Handlers set");
