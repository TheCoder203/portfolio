// %%
---layout: posttitle: Keyboard Inputdescription: Event listeners - handling keyboard inputcategories: [Javascript, Lesson]permalink: /keyboard-input-lessonauthor: Krish Kcodemirror: true---

// %% [markdown]
// ## Keyboard Input
//
// Learning from AstroPlatformer

// %%
%%js
const keys = {w:false, a:false};
function keyDown(e) {if(e.key==="w") keys.w=true;}
function keyUp(e) {if(e.key==="w") keys.w=false;}
console.log("Handlers set");
