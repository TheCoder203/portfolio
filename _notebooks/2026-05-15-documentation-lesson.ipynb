// %%
---layout: posttitle: Documentationdescription: JSDoc - documenting functionscategories: [Javascript, Lesson]permalink: /documentation-lessonauthor: Krish Kcodemirror: true---

// %% [markdown]
// ## Documentation
//
// Learning from AstroPlatformer

// %%
%%js
/**
* Scale a platform
* @param {Object} src - Platform data
* @param {number} scale - Scale factor
*/
function scale(src, scale) {
  return {x: src.x * scale};
}
console.log("Function documented");
