// %%
---layout: posttitle: Code Commentsdescription: Comments - explaining code with commentscategories: [Javascript, Lesson]permalink: /code-comments-lessonauthor: Krish Kcodemirror: true---

// %% [markdown]
// ## Code Comments
//
// Learning from AstroPlatformer

// %%
%%js
// Load coins from storage
const saved = parseInt(localStorage.getItem("coinsCollected") || "0") || 0;
// Add one more
const total = saved + 1;
console.log("Total:", total);
