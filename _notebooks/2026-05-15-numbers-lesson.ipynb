// %% [markdown]
// ---
// layout: post
// title: Numbers
// description: Lesson for numbers
// categories: [Javascript, Lesson]
// permalink: /numbers-lesson
// author: Krish K
// codemirror: true
// ---

// %% [markdown]
// ## Numbers
//
// Learning from AstroPlatformer

// %%
%%js
// CODE_RUNNER: numbers

const px = 30, py = 320, platX = 40, platY = 290;
const dist = Math.sqrt((px-platX)**2 + (py-platY)**2);
console.log("Distance:", dist.toFixed(1));
const total = 5 + 1;
console.log("Coins:", total);
