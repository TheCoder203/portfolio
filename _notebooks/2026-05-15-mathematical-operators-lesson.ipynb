// %% [markdown]
// ---
// layout: post
// title: Mathematical Operators
// description: Lesson for mathematical-operators
// categories: [Javascript, Lesson]
// permalink: /mathematical-operators-lesson
// author: Krish K
// codemirror: true
// ---

// %% [markdown]
// ## Mathematical Operators
//
// Learning from AstroPlatformer

// %%
%%js
// CODE_RUNNER: mathematical-operators

const baseW = 650;
const screenW = 800;
const scale = screenW / baseW;
console.log("Scale:", scale.toFixed(2));
const gravity = 0.52;
let vy = 0;
vy += gravity;
console.log("Velocity:", vy);
