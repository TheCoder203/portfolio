// %%
---layout: posttitle: Mathematical Operatorsdescription: Math operators - arithmetic operationscategories: [Javascript, Lesson]permalink: /mathematical-operators-lessonauthor: Krish Kcodemirror: true---

// %% [markdown]
// ## Mathematical Operators
//
// Learning from AstroPlatformer

// %%
%%js
const baseW = 650;
const screenW = 800;
const scale = screenW / baseW;
console.log("Scale:", scale.toFixed(2));
const gravity = 0.52;
let vy = 0;
vy += gravity;
console.log("Velocity:", vy);
