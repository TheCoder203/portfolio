// %%
---layout: posttitle: Configurationdescription: Config objects - game configurationcategories: [Javascript, Lesson]permalink: /gameenv-configuration-lessonauthor: Krish Kcodemirror: true---

// %% [markdown]
// ## Configuration
//
// Learning from AstroPlatformer

// %%
%%js
const config = {
  width: 650,
  height: 400,
  gravity: 0.52,
  jumpForce: -11
};
console.log("Config:", config);
