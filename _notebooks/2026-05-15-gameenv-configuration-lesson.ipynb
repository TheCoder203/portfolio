// %% [markdown]
// ---
// layout: post
// title: Gameenv Configuration
// description: Lesson for gameenv-configuration
// categories: [Javascript, Lesson]
// permalink: /gameenv-configuration-lesson
// author: Krish K
// codemirror: true
// ---

// %% [markdown]
// ## Gameenv Configuration
//
// Learning from AstroPlatformer

// %%
%%js
// CODE_RUNNER: gameenv-configuration

const config = {
  width: 650,
  height: 400,
  gravity: 0.52,
  jumpForce: -11
};
console.log("Config:", config);
