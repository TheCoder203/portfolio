// %% [markdown]
// ---
// layout: post
// title: Gameplay Testing
// description: Lesson for gameplay-testing
// categories: [Javascript, Lesson]
// permalink: /gameplay-testing-lesson
// author: Krish K
// codemirror: true
// ---

// %% [markdown]
// ## Gameplay Testing
//
// Learning from AstroPlatformer

// %%
%%js
// CODE_RUNNER: gameplay-testing

function test() {
  const coin = {collected: false};
  coin.collected = true;
  console.log(coin.collected ? "PASS" : "FAIL");
}
test();
