// %%
---layout: posttitle: Gameplay Testingdescription: Testing - verifying game behaviorcategories: [Javascript, Lesson]permalink: /gameplay-testing-lessonauthor: Krish Kcodemirror: true---

// %% [markdown]
// ## Gameplay Testing
//
// Learning from AstroPlatformer

// %%
%%js
function test() {
  const coin = {collected: false};
  coin.collected = true;
  console.log(coin.collected ? "PASS" : "FAIL");
}
test();
