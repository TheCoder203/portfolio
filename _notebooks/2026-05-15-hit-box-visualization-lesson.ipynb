// %% [markdown]
// ---
// layout: post
// title: Hit Box Visualization
// description: Lesson for hit-box-visualization
// categories: [Javascript, Lesson]
// permalink: /hit-box-visualization-lesson
// author: Krish K
// codemirror: true
// ---

// %% [markdown]
// ## Hit Box Visualization
//
// Learning from AstroPlatformer

// %%
%%js
// CODE_RUNNER: hit-box-visualization

const coin = {x:90,y:268,w:14,h:14};
const hbw = coin.w * 0.2;
const hbh = coin.h * 0.2;
console.log("Hitbox:", hbw, "x", hbh);
