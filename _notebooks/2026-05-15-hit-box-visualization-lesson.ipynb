// %%
---layout: posttitle: Hitbox Visualizationdescription: Collision boxes - visualizing collision zonescategories: [Javascript, Lesson]permalink: /hit-box-visualization-lessonauthor: Krish Kcodemirror: true---

// %% [markdown]
// ## Hitbox Visualization
//
// Learning from AstroPlatformer

// %%
%%js
const coin = {x:90,y:268,w:14,h:14};
const hbw = coin.w * 0.2;
const hbh = coin.h * 0.2;
console.log("Hitbox:", hbw, "x", hbh);
