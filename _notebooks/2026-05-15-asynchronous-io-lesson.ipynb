// %%
---layout: posttitle: Asynchronous I/Odescription: Asynchronous operations - setTimeout for delayed actionscategories: [Javascript, Lesson]permalink: /asynchronous-io-lessonauthor: Krish Kcodemirror: true---

// %% [markdown]
// ## Asynchronous I/O
//
// Learning from AstroPlatformer

// %%
%%js
console.log("Start");
setTimeout(() => console.log("After 500ms"), 500);
console.log("Waiting...");
