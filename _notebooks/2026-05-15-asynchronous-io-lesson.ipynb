// %% [markdown]
// ---
// layout: post
// title: Asynchronous Io
// description: Lesson for asynchronous-io
// categories: [Javascript, Lesson]
// permalink: /asynchronous-io-lesson
// author: Krish K
// codemirror: true
// ---

// %% [markdown]
// ## Asynchronous Io
//
// Learning from AstroPlatformer

// %%
%%js
// CODE_RUNNER: asynchronous-io

console.log("Start");
setTimeout(() => console.log("After 500ms"), 500);
console.log("Waiting...");
