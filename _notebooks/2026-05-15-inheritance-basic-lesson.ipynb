// %%
---layout: posttitle: Inheritancedescription: Class inheritance - extending base classescategories: [Javascript, Lesson]permalink: /inheritance-basic-lessonauthor: Krish Kcodemirror: true---

// %% [markdown]
// ## Inheritance
//
// Learning from AstroPlatformer

// %%
%%js
class GameObject {update(){console.log("Update");}}
class Coin extends GameObject {}
const c = new Coin();
c.update();
