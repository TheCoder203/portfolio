// %%
---layout: posttitle: Writing Classesdescription: class keyword - defining classescategories: [Javascript, Lesson]permalink: /writing-classes-lessonauthor: Krish Kcodemirror: true---

// %% [markdown]
// ## Writing Classes
//
// Learning from AstroPlatformer

// %%
%%js
class Platform {
  constructor(id, x, y) {
    this.id = id; this.x = x; this.y = y;
  }
  update() {
    console.log("Platform", this.id);
  }
}
const p = new Platform("p1", 40, 290);
p.update();
