// %% [markdown]
// ---
// layout: post
// title: Writing Classes
// description: Lesson for writing-classes
// categories: [Javascript, Lesson]
// permalink: /writing-classes-lesson
// author: Krish K
// codemirror: true
// ---

// %% [markdown]
// ## Writing Classes
//
// Learning from AstroPlatformer

// %%
%%js
// CODE_RUNNER: writing-classes

class Platform {
  constructor(id, x, y) {
    this.id = id; this.x = x; this.y = y;
  }
  update() {
    console.log("Platform", this.id);
  }
}
const p = new Platform("p1", 40, 290);
p.update();
