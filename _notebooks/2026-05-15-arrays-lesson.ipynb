// %%
---
layout: post
title: Arrays
description: Array operations - using arrays to store platforms and coins
categories: [Javascript, Lesson]
permalink: /arrays-lesson
author: Krish K
codemirror: true
---

// %% [markdown]
// ## Arrays
//
// Learning from AstroPlatformer

// %%
%%js
const platforms = [{id:"p1",x:40,y:290},{id:"p2",x:190,y:230}];
const coins = [{id:"coin1",x:90,y:268}];
console.log("Platforms:", platforms.length);
console.log("Coins:", coins.length);
