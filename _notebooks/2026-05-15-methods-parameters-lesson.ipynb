// %% [markdown]
// ---
// layout: post
// title: Methods Parameters
// description: Lesson for methods-parameters
// categories: [Javascript, Lesson]
// permalink: /methods-parameters-lesson
// author: Krish K
// codemirror: true
// ---

// %% [markdown]
// ## Methods Parameters
//
// Learning from AstroPlatformer

// %%
%%js
// CODE_RUNNER: methods-parameters

function scale(obj, sx, sy) {
  return {id:obj.id, x:obj.x*sx, y:obj.y*sy};
}
const result = scale({id:"p1",x:40,y:290}, 1.5, 1.5);
console.log(result);
