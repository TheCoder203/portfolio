// %%
---layout: posttitle: Canvas Renderingdescription: DOM rendering - creating and styling game elementscategories: [Javascript, Lesson]permalink: /canvas-rendering-lessonauthor: Krish Kcodemirror: true---

// %% [markdown]
// ## Canvas Rendering
//
// Learning from AstroPlatformer

// %%
%%js
const el = document.createElement("div");
Object.assign(el.style, {position:"absolute",width:"100px",height:"12px",background:"#4a9eff"});
console.log("Element created:", el);
