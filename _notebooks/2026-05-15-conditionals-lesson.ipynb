// %%
---layout: posttitle: Conditionalsdescription: if/else statements - branching logiccategories: [Javascript, Lesson]permalink: /conditionals-lessonauthor: Krish Kcodemirror: true---

// %% [markdown]
// ## Conditionals
//
// Learning from AstroPlatformer

// %%
%%js
const collected = false;
if (!collected) {
  console.log("Coin available");
} else {
  console.log("Already collected");
}
