// %% [markdown]
// ---
// layout: post
// title: Conditionals
// description: Lesson for conditionals
// categories: [Javascript, Lesson]
// permalink: /conditionals-lesson
// author: Krish K
// codemirror: true
// ---

// %% [markdown]
// ## Conditionals
//
// Learning from AstroPlatformer

// %%
%%js
// CODE_RUNNER: conditionals

const collected = false;
if (!collected) {
  console.log("Coin available");
} else {
  console.log("Already collected");
}
