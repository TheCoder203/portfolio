// %%
---layout: posttitle: Nested Conditionsdescription: Nested if statements - complex conditionscategories: [Javascript, Lesson]permalink: /nested-conditions-lessonauthor: Krish Kcodemirror: true---

// %% [markdown]
// ## Nested Conditions
//
// Learning from AstroPlatformer

// %%
%%js
const a = true, b = true, c = false;
if (a) {
  if (b) {
    if (!c) console.log("All nested conditions pass");
  }
}
