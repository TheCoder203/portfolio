// %% [markdown]
// ---
// layout: post
// title: Nested Conditions
// description: Lesson for nested-conditions
// categories: [Javascript, Lesson]
// permalink: /nested-conditions-lesson
// author: Krish K
// codemirror: true
// ---

// %% [markdown]
// ## Nested Conditions
//
// Learning from AstroPlatformer

// %%
%%js
// CODE_RUNNER: nested-conditions

const a = true, b = true, c = false;
if (a) {
  if (b) {
    if (!c) console.log("All nested conditions pass");
  }
}
