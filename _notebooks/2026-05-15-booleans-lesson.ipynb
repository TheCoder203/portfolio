// %% [markdown]
// ---
// layout: post
// title: Booleans
// description: Lesson for booleans
// categories: [Javascript, Lesson]
// permalink: /booleans-lesson
// author: Krish K
// codemirror: true
// ---

// %% [markdown]
// ## Booleans
//
// Learning from AstroPlatformer

// %%
%%js
// CODE_RUNNER: booleans

const alive = true;
const jumping = false;
const collected = false;
console.log("Alive:", alive, "Jumping:", jumping);
