// %%
---layout: posttitle: Booleansdescription: Boolean values - true/false states in game logiccategories: [Javascript, Lesson]permalink: /booleans-lessonauthor: Krish Kcodemirror: true---

// %% [markdown]
// ## Booleans
//
// Learning from AstroPlatformer

// %%
%%js
const alive = true;
const jumping = false;
const collected = false;
console.log("Alive:", alive, "Jumping:", jumping);
