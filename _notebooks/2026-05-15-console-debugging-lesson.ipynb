// %%
---layout: posttitle: Console Debuggingdescription: console.log - debugging with console outputcategories: [Javascript, Lesson]permalink: /console-debugging-lessonauthor: Krish Kcodemirror: true---

// %% [markdown]
// ## Console Debugging
//
// Learning from AstroPlatformer

// %%
%%js
const state = {level:1, health:3, x:30, y:320};
console.log("State:", state);
console.log("Position:", state.x, state.y);
