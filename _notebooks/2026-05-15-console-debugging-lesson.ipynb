// %% [markdown]
// ---
// layout: post
// title: Console Debugging
// description: Lesson for console-debugging
// categories: [Javascript, Lesson]
// permalink: /console-debugging-lesson
// author: Krish K
// codemirror: true
// ---

// %% [markdown]
// ## Console Debugging
//
// Learning from AstroPlatformer

// %%
%%js
// CODE_RUNNER: console-debugging

const state = {level:1, health:3, x:30, y:320};
console.log("State:", state);
console.log("Position:", state.x, state.y);
