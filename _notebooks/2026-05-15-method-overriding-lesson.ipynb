// %%
---
layout: post
title: Method Overriding
description: Override methods - customizing inherited methods
categories: [Javascript, Lesson]
permalink: /method-overriding-lesson
author: Krish K
codemirror: true
---

// %% [markdown]
// ## Method Overriding
//
// Learning from AstroPlatformer

// %%
%%js
class Coin {update(){console.log("Base");}}
class GameCoin extends Coin {update(){console.log("Override");}}
const c = new GameCoin();
c.update();
