// %% [markdown]
// ---
// layout: post
// title: Boolean Expressions
// description: Lesson for boolean-expressions
// categories: [Javascript, Lesson]
// permalink: /boolean-expressions-lesson
// author: Krish K
// codemirror: true
// ---

// %% [markdown]
// ## Boolean Expressions
//
// Learning from AstroPlatformer

// %%
%%js
// CODE_RUNNER: boolean-expressions

const ground = true;
const hasJumped = false;
const canJump = ground && !hasJumped;
console.log("Can jump?", canJump);
