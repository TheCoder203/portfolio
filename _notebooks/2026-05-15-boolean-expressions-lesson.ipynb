// %%
---layout: posttitle: Boolean Expressionsdescription: Boolean expressions - combining conditionscategories: [Javascript, Lesson]permalink: /boolean-expressions-lessonauthor: Krish Kcodemirror: true---

// %% [markdown]
// ## Boolean Expressions
//
// Learning from AstroPlatformer

// %%
%%js
const ground = true;
const hasJumped = false;
const canJump = ground && !hasJumped;
console.log("Can jump?", canJump);
