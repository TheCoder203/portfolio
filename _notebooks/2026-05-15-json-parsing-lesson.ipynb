// %% [markdown]
// ---
// layout: post
// title: Json Parsing
// description: Lesson for json-parsing
// categories: [Javascript, Lesson]
// permalink: /json-parsing-lesson
// author: Krish K
// codemirror: true
// ---

// %% [markdown]
// ## Json Parsing
//
// Learning from AstroPlatformer

// %%
%%js
// CODE_RUNNER: json-parsing

const obj = {name:"Level1", width:650};
const json = JSON.stringify(obj);
console.log("JSON:", json);
const parsed = JSON.parse(json);
console.log("Parsed:", parsed.name);
