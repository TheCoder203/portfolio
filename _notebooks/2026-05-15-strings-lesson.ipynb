// %%
---layout: posttitle: Stringsdescription: String basics - creating and using stringscategories: [Javascript, Lesson]permalink: /strings-lessonauthor: Krish Kcodemirror: true---

// %% [markdown]
// ## Strings
//
// Learning from AstroPlatformer

// %%
%%js
const game = "AstroPlatformer";
const level = "Crater";
console.log("Game:", game);
console.log("Level:", level);
const intro = game + ": " + level;
console.log("Intro:", intro);
