// %% [markdown]
// ---
// layout: post
// title: Strings
// description: Lesson for strings
// categories: [Javascript, Lesson]
// permalink: /strings-lesson
// author: Krish K
// codemirror: true
// ---

// %% [markdown]
// ## Strings
//
// Learning from AstroPlatformer

// %%
%%js
// CODE_RUNNER: strings

const game = "AstroPlatformer";
const level = "Crater";
console.log("Game:", game);
console.log("Level:", level);
const intro = game + ": " + level;
console.log("Intro:", intro);
